# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dat = pd.read_csv('data_viz.csv')

# %%
dat
# Out:
#              Timestamp  Gender    Age  Location Time of class (pm)  \
# 0    1/3/2022 19:09:29    Male  16-30  Pakistan              10:30
# 1    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 2    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 3    1/3/2022 19:09:33    Male  30-40  Pakistan              09:30
# 4    1/3/2022 19:09:34    Male  16-30      East              09:30
# ..                 ...     ...    ...       ...                ...
# 301  1/3/2022 19:11:51    Male  16-30  Pakistan              09:30
# 302  1/3/2022 19:11:52    Male  16-30  Pakistan              10:30
# 303  1/3/2022 19:11:53    Male  16-30  Pakistan              10:00
# 304  1/3/2022 19:11:54  Female  16-30  Pakistan              10:30
# 305  1/3/2022 19:11:55    Male  16-30  Pakistan              10:30
#
#      Duration (min)
# 0                60
# 1                60
# 2                30
# 3                30
# 4                60
# ..              ...
# ...

# %%
sns.set_theme(style="ticks", color_codes=True)
p = sns.countplot(x="Gender",hue="Age",data = dat)
plt.show()

# %%
titanic  =pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
sns.countplot(x='sex',hue='survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Step 1
import seaborn as sns
import matplotlib.pyplot as plt
# Step 2 - Set Theme
sns.set_theme(style="ticks",color_codes=True)
# Step 3 - Load Dataset
kashti = sns.load_dataset('titanic')
#print(kashti)

#  Step 4 - plot basic graph with one variable
# p = sns.countplot(x="sex",data= kashti)
# plt.show()

#  Step 5 - plot basic graph with  2 variables
# p = sns.countplot(x='sex',data=kashti,hue='survived')
# plt.show()

# Step 6 - plot basic graph with  2 variables
p = sns.countplot(x='sex',data=kashti,hue='survived')
p.set_title("Count plot")
plt.show()

# %%
g = sns.FacetGrid(titanic,row="sex",hue='sibsp')
g= (g.map(plt.scatter,"age","fare").add_legend())
plt.show()

# %%
import pandas as pd
chila = pd.read_csv('data_viz.csv')
#print(chila)
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_theme(style='ticks',color_codes=True)
p = sns.countplot(x='Age',hue="Location",data=chila)
plt.show()
