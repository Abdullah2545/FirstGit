# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Chilla_data2_for_plots.csv')

# %%
data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %% [markdown]
# ## Line plot with Title

# %%
sns.lineplot(x="Age",y="Your Weight in kg? (float)",data = data)
plt.title('Line plot (Weight vs Age)')
plt.show()

# %% [markdown]
# ## set style

# %%
sns.set_style(style=None,rc = None)

# %%
sns.lineplot(x="Age",y="Your Weight in kg? (float)",data = data)
plt.title('Line plot (Weight vs Age)')
sns.set_style(style='dark')
plt.show()

# %% [markdown]
# ## size of figure

# %%
plt.figure(figsize=(8,6),)
sns.lineplot(x="Age",y="Your Weight in kg? (float)",data = data)
plt.title('Line plot (Weight vs Age)')
sns.set_style(style='dark')
plt.show()

# %% [markdown]
# # Bar plot

# %%
kashti = pd.read_csv('titanic.csv')
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="survived", hue='pclass',data=kashti)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="survived", hue='pclass',data=kashti,order=['female','male'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="survived", hue='pclass',data=kashti,order=['female','male'],color='brown',ci=None)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="fare", hue='pclass',data=kashti,order=['female','male'],estimator=np.median,color='brown',ci=None,palette='pastel')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="survived", hue='pclass',data=kashti,order=['female','male'],color='brown',estimator=np.mean,palette='pastel')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="fare", hue='pclass',data=kashti,order=['female','male'],color='brown',estimator=np.median,palette='pastel')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="fare", hue='pclass',data=kashti,order=['female','male'],color='brown',
            estimator=np.median,palette='pastel',saturation=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="fare",y="sex", hue='pclass',data=kashti,order=['female','male'],color='brown',
            estimator=np.median,palette='pastel',saturation=0.8)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex",y="fare", hue='pclass',data=kashti,
           linewidth=3.5,facecolor=(1,0.2,1,1),
           errcolor=".6",edgecolor='.4')
plt.show()

# %% [markdown]
# # Boxplot

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
sns.boxplot(x="sex",y="fare", hue='pclass',data=kashti,
           linewidth=3.5,)
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
sns.boxplot(x="fare",y="sex", hue='pclass',data=kashti,
           linewidth=3.5,hue_order=[3,2,1],palette=["C0", "C1", "k"])
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
sns.boxplot(x="fare", hue='pclass',data=kashti,
           linewidth=3.5,hue_order=[3,2,1],palette=["C0", "C1", "k"])
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
sns.boxplot(y="fare",data=kashti,
           linewidth=3.5,hue_order=[3,2,1],palette=["C0", "C1", "k"])
plt.show()

# %% [markdown]
# ## custom bar plots

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
sns.boxplot(x="sex",y="age",data=kashti,
            showmeans=True,
            meanprops={'marker':'*',
                      'markersize':'12',
                      'markeredgecolor':'yellow'},
           linewidth=3.5,)
plt.title('Titanic',size=26,weight='bold')
plt.xlabel('Sex (Gender)',size=16,weight='bold')
plt.ylabel('Age',size=16,weight='bold')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
g = sns.FacetGrid(kashti,col = 'pclass')
g.map(sns.boxplot,x=kashti["sex"],y=kashti["age"],showmeans=True,
          meanprops={'marker':'*',
                     'markersize':'12',
                     'markeredgecolor':'yellow'})
# sns.boxplot(x="sex",y="age",data=kashti,
#             showmeans=True,
#             meanprops={'marker':'*',
#                       'markersize':'12',
#                       'markeredgecolor':'yellow'},
#            linewidth=3.5,)
# plt.title('Titanic',size=26,weight='bold')
# plt.xlabel('Sex (Gender)',size=16,weight='bold')
# plt.ylabel('Age',size=16,weight='bold')
plt.show()
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,6))
g = sns.FacetGrid(kashti,col = 'pclass')
g.map_dataframe(sns.boxplot,"sex","age",showmeans=True,
          meanprops={'marker':'*',
                     'markersize':'12',
                     'markeredgecolor':'yellow'})
g.set_axis_labels("Sex(Gender)",'Age')
g.set_titles(col_template='{col_name} Fare')
# sns.boxplot(x="sex",y="age",data=kashti,
#             showmeans=True,
#             meanprops={'marker':'*',
#                       'markersize':'12',
#                       'markeredgecolor':'yellow'},
#            linewidth=3.5,)
# plt.title('Titanic',size=26,weight='bold')
# plt.xlabel('Sex (Gender)',size=16,weight='bold')
# plt.ylabel('Age',size=16,weight='bold')
plt.show()

# %% [markdown]
# # FacetGrid

# %%
nukta = sns.load_dataset('titanic')
nukta.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
a = sns.FacetGrid(nukta,col='who')
a.map_dataframe(sns.boxplot,x='sex',y='fare')

# %% [markdown]
# # Box plot adopted from gallery

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")


# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="sex", y="fare",
            hue="pclass", palette=["m", "g"],
            data=nukta)
sns.despine(offset=10, trim=True)
